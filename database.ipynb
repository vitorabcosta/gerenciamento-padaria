# %%
from sqlalchemy import create_engine, Column, Integer, String, Float, ForeignKey, Table
from sqlalchemy.orm import relationship, declarative_base, sessionmaker

Base = declarative_base()

# Tabela de Associação (prod_venda)
prod_venda = Table('prod_venda', Base.metadata,
    Column('produto_id', Integer, ForeignKey('produto.id_produto')),
    Column('venda_id', Integer, ForeignKey('venda.id_venda'))
)

class Produto(Base):
    __tablename__ = 'produto'

    id_produto = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    quantity = Column(Integer, default=0)
    price = Column(Float, default=0.0)

    # Adicionando relação com a tabela de prod_venda
    vendas = relationship('Venda', secondary=prod_venda, back_populates='produtos')

class Venda(Base):
    __tablename__ = 'venda'

    id_venda = Column(Integer, primary_key=True)
    valor_total = Column(Float, nullable=False)

    # Adicionando relação com a tabela de Prod_Venda
    produtos = relationship('Produto', secondary=prod_venda, back_populates='vendas')


# Criação do banco de dados
engine = create_engine('sqlite:///padaria.db', echo=True)
Base.metadata.create_all(engine)

# Criação de uma sessão para interação com o banco de dados
Session = sessionmaker(bind=engine)
session = Session()
# Out:
# 2024-02-20 11:00:00,684 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-20 11:00:00,685 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("prod_venda")
# 2024-02-20 11:00:00,689 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,691 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("prod_venda")
# 2024-02-20 11:00:00,693 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,694 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("produto")
# 2024-02-20 11:00:00,695 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,697 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("produto")
# 2024-02-20 11:00:00,701 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,703 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("venda")
# 2024-02-20 11:00:00,705 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,707 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("venda")
# 2024-02-20 11:00:00,709 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-20 11:00:00,711 INFO sqlalchemy.engine.Engine
# CREATE TABLE produto (
# 	id_produto INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	quantity INTEGER,
# 	price FLOAT,
# 	PRIMARY KEY (id_produto)
# )
#
#
# 2024-02-20 11:00:00,713 INFO sqlalchemy.engine.Engine [no key 0.00200s] ()
# 2024-02-20 11:00:00,804 INFO sqlalchemy.engine.Engine
# CREATE TABLE venda (
# 	id_venda INTEGER NOT NULL,
# 	valor_total FLOAT NOT NULL,
# 	PRIMARY KEY (id_venda)
# )
#
#
# 2024-02-20 11:00:00,805 INFO sqlalchemy.engine.Engine [no key 0.00125s] ()
# 2024-02-20 11:00:00,960 INFO sqlalchemy.engine.Engine
# CREATE TABLE prod_venda (
# 	produto_id INTEGER,
# 	venda_id INTEGER,
# 	FOREIGN KEY(produto_id) REFERENCES produto (id_produto),
# 	FOREIGN KEY(venda_id) REFERENCES venda (id_venda)
# )
#
#
# 2024-02-20 11:00:00,983 INFO sqlalchemy.engine.Engine [no key 0.02368s] ()
# 2024-02-20 11:00:01,078 INFO sqlalchemy.engine.Engine COMMIT
